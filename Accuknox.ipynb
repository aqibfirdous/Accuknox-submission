# %% [markdown]
# <a href="https://colab.research.google.com/github/aqibfirdous/Accuknox-submission/blob/main/Accuknox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Q1:
# API Data Retrieval and Storage: You are tasked with fetching data from an external REST API, storing it in a local SQLite database, and displaying the retrieved data. The API provides a list of books in JSON format with attributes like title, author, and publication year.

# %%
import requests
import sqlite3

# Fetch data from FREE Open Library API
url = "https://openlibrary.org/search.json?q=python"
response = requests.get(url)
data = response.json()

books = data["docs"][:10]
conn = sqlite3.connect("books.db")
cursor = conn.cursor()

print("Book data successfully stored in SQLite database.")
print("Database name: books.db")
print("Table name: books")

cursor.execute("SELECT title, author, year FROM books LIMIT 5")
rows = cursor.fetchall()

# Display the data
print("Books stored in database:\n")
for row in rows:
    title, author, year = row
    print(f"Title: {title}")
    print(f"Author: {author}")
    print(f"Publication Year: {year}")
    print("-" * 40)

conn.commit()
conn.close()
# Out:
# Book data successfully stored in SQLite database.
# Database name: books.db
# Table name: books
# Books stored in database:
#
# Title: Learning Python
# Author: Mark Lutz
# Publication Year: 1999
# ----------------------------------------
# Title: Python
# Author: Mark Lutz
# Publication Year: 1998
# ----------------------------------------
# Title: Python Cookbook
# Author: Alex Martelli
# Publication Year: 2002
# ----------------------------------------
# Title: Programming Python
# Author: Mark Lutz
# Publication Year: 1996
# ----------------------------------------
# Title: Fluent Python
# Author: Luciano Ramalho
# Publication Year: 2015
# ----------------------------------------

# %% [markdown]
# # Q2:
# Data Processing and Visualization: Given a dataset containing information about students' test scores, fetch the data from an API, calculate the average score, and create a bar chart to visualize the data.

# %%
import requests
import matplotlib.pyplot as plt
import random

# Fetch data from a free public API
url = "https://jsonplaceholder.typicode.com/posts"
response = requests.get(url).json()

names = [entry['title'] for entry in response[:10]]
scores = [random.randint(50, 100) for _ in names]
avg_score = sum(scores) / len(scores)
print("Average Score:", round(avg_score, 2))

# Plot bar chart
plt.figure(figsize=(12,8))
plt.bar(names, scores, color='skyblue')
plt.xticks(rotation=60, ha='right')
plt.ylabel("Scores")
plt.xlabel("Students (Post Titles)")
plt.title("Student Test Scores (Simulated based on Post Titles)")
plt.ylim(0, 100)
plt.tight_layout()
plt.show()
# Out:
# Average Score: 70.4

# %% [markdown]
# # Q3:
# CSV Data Import to a Database: Write a Python script that reads data from a CSV file containing user information (e.g., name, email) and inserts it into a SQLite database.

# %%
import csv
import sqlite3

conn = sqlite3.connect("users.db")
cursor = conn.cursor()

with open("users.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        cursor.execute(
            "INSERT INTO users (name, email) VALUES (?, ?)",
            (row["name"], row["email"])
        )
cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()

for row in rows:
    print(row)
conn.commit()
conn.close()
# Out:
# (1, 'Aqib', 'Firdous,aqib@example.com')
# (2, 'John', 'Doe,john@example.com')
# (3, 'Jane', 'Smith,jane@example.com')

# %% [markdown]
# # Q4:

# %%
https://github.com/aqibfirdous/AI-AGENT/blob/main/app/report_generator.py

# %% [markdown]
# # Q5:

# %%
I had created one university management system but currently i
don't have any link of that, and recently i have been working on sql lite only.

# %% [markdown]
# LLM CHATBOT ARCHITECTING

# %% [markdown]
# ![1713071979669.png](data:image/png;base64,...)
